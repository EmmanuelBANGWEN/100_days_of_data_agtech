# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('rainfall.csv')
df.head()
# Out:
#           Area  Year average_rain_fall_mm_per_year
# 0  Afghanistan  1985                           327
# 1  Afghanistan  1986                           327
# 2  Afghanistan  1987                           327
# 3  Afghanistan  1989                           327
# 4  Afghanistan  1990                           327

# %%
df['average_rain_fall_mm_per_year'].describe()
# Out:
# count     5953
# unique     173
# top        630
# freq        62
# Name: average_rain_fall_mm_per_year, dtype: object

# %%
df['Area'].describe()
# Out:
# count            6727
# unique            217
# top       Afghanistan
# freq               31
# Name: Area, dtype: object

# %%
df['Year'].describe()
# Out:
# count    6727.000000
# mean     2001.354839
# std         9.530114
# min      1985.000000
# 25%      1993.000000
# 50%      2001.000000
# 75%      2010.000000
# max      2017.000000
# Name: Year, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6727 entries, 0 to 6726
# Data columns (total 3 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Area                           6727 non-null   object
#  1   Year                           6727 non-null   int64
#  2   average_rain_fall_mm_per_year  5953 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 157.8+ KB

# %%
df.head()
# Out:
#           Area  Year average_rain_fall_mm_per_year
# 0  Afghanistan  1985                           327
# 1  Afghanistan  1986                           327
# 2  Afghanistan  1987                           327
# 3  Afghanistan  1989                           327
# 4  Afghanistan  1990                           327

# %%
df['average_rain_fall_mm_per_year'].head()
# Out:
# 0    327
# 1    327
# 2    327
# 3    327
# 4    327
# Name: average_rain_fall_mm_per_year, dtype: object

# %%
df.sample(5)
# Out:
#                        Area  Year average_rain_fall_mm_per_year
# 6022                   Togo  1994                          1168
# 3466                Lesotho  2012                           788
# 5134  Sao Tome and Principe  2006                          3200
# 3629       Macao SAR, China  1987                           NaN
# 4915            Puerto Rico  2004                          2054

# %%
list =[]
for a in df['Area']:

    if a == 'Gabon':
        list.append(a)
print(len(list))
# Out:
# 31

# %%
list
# Out:
# ['Gabon',
#  'Gabon',
#  'Gabon',
#  'Gabon',
#  'Gabon',
#  'Gabon',
#  'Gabon',
#  'Gabon',
#  'Gabon',
#  'Gabon',
#  'Gabon',
#  'Gabon',
#  'Gabon',
#  'Gabon',
#  'Gabon',
#  'Gabon',
#  'Gabon',
#  'Gabon',
#  'Gabon',
#  'Gabon',
#  'Gabon',
#  'Gabon',
#  'Gabon',
#  'Gabon',
#  'Gabon',
#  'Gabon',
#  'Gabon',
#  'Gabon',
#  'Gabon',
#  'Gabon',
#  'Gabon']

# %%
df.sample(50)
# Out:
#                            Area  Year average_rain_fall_mm_per_year
# 3637           Macao SAR, China  1996                           NaN
# 4890                   Portugal  2010                           854
# 1146             Cayman Islands  2017                           NaN
# 6407              United States  2008                           715
# 2921                Isle of Man  1993                           NaN
# 4336                      Nepal  2014                          1500
# 1605                     Cyprus  2011                           498
# 651                     Bermuda  1985                           NaN
# 3922                 Mauritania  2002                            92
# 5988                Timor-Leste  1991                          1500
# 5913                 Tajikistan  2010                           691
# 3717                 Madagascar  2015                          1513
# 3796                   Maldives  2000                          1972
# ...

# %%
rainfall_Bangladesh = df[df['Area']=='Bangladesh']
rainfall_Bangladesh.head()
# Out:
#            Area  Year average_rain_fall_mm_per_year
# 465  Bangladesh  1985                          2666
# 466  Bangladesh  1986                          2666
# 467  Bangladesh  1987                          2666
# 468  Bangladesh  1989                          2666
# 469  Bangladesh  1990                          2666

# %%
rainfall_Bangladesh['average_rain_fall_mm_per_year'].min()
# Out:
# '2666'

# %%
plt.plot(rainfall_Bangladesh['Year'],
         rainfall_Bangladesh['average_rain_fall_mm_per_year'])

plt.title('Analyse des précipitations au Bangladesh')
plt.xlabel('Année')
plt.ylabel('Precipitation')

plt.show()

# %%
df2=df.fillna(0)
df2
# Out:
#              Area  Year average_rain_fall_mm_per_year
# 0     Afghanistan  1985                           327
# 1     Afghanistan  1986                           327
# 2     Afghanistan  1987                           327
# 3     Afghanistan  1989                           327
# 4     Afghanistan  1990                           327
# ...           ...   ...                           ...
# 6722     Zimbabwe  2013                           657
# 6723     Zimbabwe  2014                           657
# 6724     Zimbabwe  2015                           657
# 6725     Zimbabwe  2016                           657
# 6726     Zimbabwe  2017                           657
#
# [6727 rows x 3 columns]

# %%
df2["average_rain_fall_mm_per_year"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 5953 entries, 0 to 6726
# Series name: average_rain_fall_mm_per_year
# Non-Null Count  Dtype
# --------------  -----
# 5953 non-null   object
# dtypes: object(1)
# memory usage: 93.0+ KB

# %%
rainfall_max = df2["average_rain_fall_mm_per_year"].max()
rainfall_max
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3048\3997693623.py in ?()
# ----> 1 rainfall_max = df2["average_rain_fall_mm_per_year"].top()
#       2 rainfall_max
#
# c:\Users\AB SOLUTIONS\Documents\Full_learning\data_code\100_days_of_data\data\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'top'
